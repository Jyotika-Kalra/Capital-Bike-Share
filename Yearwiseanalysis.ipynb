# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score

# %%
#Concating 12 months data for the year 2019.
jan_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201901-capitalbikeshare-tripdata.csv')
feb_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201902-capitalbikeshare-tripdata.csv')
mar_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201903-capitalbikeshare-tripdata.csv')
apr_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201904-capitalbikeshare-tripdata.csv')
may_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201905-capitalbikeshare-tripdata.csv')
jun_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201906-capitalbikeshare-tripdata.csv')
jul_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201907-capitalbikeshare-tripdata.csv')
aug_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201908-capitalbikeshare-tripdata.csv')
sep_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201909-capitalbikeshare-tripdata.csv')
oct_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201910-capitalbikeshare-tripdata.csv')
nov_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201911-capitalbikeshare-tripdata.csv')
dec_df19 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2019 data\201912-capitalbikeshare-tripdata.csv')
df19 = pd.concat([jan_df19, feb_df19, mar_df19, apr_df19, may_df19, jun_df19, jul_df19, aug_df19, sep_df19, oct_df19, nov_df19, dec_df19], axis=0)

# %%
#Concating 12 months data for the year 2020.
jan_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202001-capitalbikeshare-tripdata.csv')
feb_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202002-capitalbikeshare-tripdata.csv')
mar_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202003-capitalbikeshare-tripdata.csv')
apr_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202004-capitalbikeshare-tripdata.csv')
may_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202005-capitalbikeshare-tripdata.csv')
jun_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202006-capitalbikeshare-tripdata.csv')
jul_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202007-capitalbikeshare-tripdata.csv')
aug_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202008-capitalbikeshare-tripdata.csv')
sep_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202009-capitalbikeshare-tripdata.csv')
oct_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202010-capitalbikeshare-tripdata.csv')
nov_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202011-capitalbikeshare-tripdata.csv')
dec_df20 = pd.read_csv(r'C:\Users\jyoti\Desktop\DATA SCIENCE\Capital Bike Sharing\2020 data\202012-capitalbikeshare-tripdata.csv')
df20 = pd.concat([jan_df20, feb_df20, mar_df20, apr_df20, may_df20, jun_df20, jul_df20, aug_df20, sep_df20, oct_df20, nov_df20, dec_df20], axis=0)

# %%
df11 = pd.read_csv(r'2011 data\2011-capitalbikeshare-tripdata.csv')

# %%
q112 = pd.read_csv(r'2012 data\2012Q1-capitalbikeshare-tripdata.csv')
q212 = pd.read_csv(r'2012 data\2012Q2-capitalbikeshare-tripdata.csv')
q312 = pd.read_csv(r'2012 data\2012Q3-capitalbikeshare-tripdata.csv')
q412 = pd.read_csv(r'2012 data\2012Q4-capitalbikeshare-tripdata.csv')
df12 = pd.concat([q112, q212, q312, q412], axis=0)

# %%
q113 = pd.read_csv(r'2013 data\2013Q1-capitalbikeshare-tripdata.csv')
q213 = pd.read_csv(r'2013 data\2013Q1-capitalbikeshare-tripdata.csv')
q313 = pd.read_csv(r'2013 data\2013Q1-capitalbikeshare-tripdata.csv')
q413 = pd.read_csv(r'2013 data\2013Q1-capitalbikeshare-tripdata.csv')
df13 = pd.concat([q113, q213, q313, q413], axis=0)

# %%
q114 = pd.read_csv(r'2014 data\2014Q1-capitalbikeshare-tripdata.csv')
q214 = pd.read_csv(r'2014 data\2014Q2-capitalbikeshare-tripdata.csv')
q314 = pd.read_csv(r'2014 data\2014Q3-capitalbikeshare-tripdata.csv')
q414 = pd.read_csv(r'2014 data\2014Q4-capitalbikeshare-tripdata.csv')
df14 = pd.concat([q114, q214, q314, q414], axis=0)

# %%
q115 = pd.read_csv(r'2015 data\2015Q1-capitalbikeshare-tripdata.csv')
q215 = pd.read_csv(r'2015 data\2015Q2-capitalbikeshare-tripdata.csv')
q315 = pd.read_csv(r'2015 data\2015Q3-capitalbikeshare-tripdata.csv')
q415 = pd.read_csv(r'2015 data\2015Q4-capitalbikeshare-tripdata.csv')
df15 = pd.concat([q115, q215, q315, q415], axis=0)

# %%
ind11 = pd.DatetimeIndex(df11['Start date']) #Use pandas.DatatimeIndex class for dealing with dates
df11['date'] = ind11.date.astype('datetime64') #creates an index with values cast to dtypes
df11['hour'] = ind11.hour #returns the hour from the datetime object
df11['Dayofweek'] = ind11.dayofweek #returns the day of the week (Monday = 0, Sunday = 6)
df11['DOW'] = ind11.strftime('%a') #%a is the format string for Weekday Abbreviated name (Sun,Mon, etc.)

# %%
ind12 = pd.DatetimeIndex(df12['Start date']) #Use pandas.DatatimeIndex class for dealing with dates
df12['date'] = ind12.date.astype('datetime64') #creates an index with values cast to dtypes
df12['hour'] = ind12.hour #returns the hour from the datetime object
df12['Dayofweek'] = ind12.dayofweek #returns the day of the week (Monday = 0, Sunday = 6)
df12['DOW'] = ind12.strftime('%a') #%a is the format string for Weekday Abbreviated name (Sun,Mon, etc.)

# %%
ind13 = pd.DatetimeIndex(df13['Start date']) #Use pandas.DatatimeIndex class for dealing with dates
df13['date'] = ind13.date.astype('datetime64') #creates an index with values cast to dtypes
df13['hour'] = ind13.hour #returns the hour from the datetime object
df13['Dayofweek'] = ind13.dayofweek #returns the day of the week (Monday = 0, Sunday = 6)
df13['DOW'] = ind13.strftime('%a') #%a is the format string for Weekday Abbreviated name (Sun,Mon, etc.)

# %%
ind14 = pd.DatetimeIndex(df14['Start date']) #Use pandas.DatatimeIndex class for dealing with dates
df14['date'] = ind14.date.astype('datetime64') #creates an index with values cast to dtypes
df14['hour'] = ind14.hour #returns the hour from the datetime object
df14['Dayofweek'] = ind14.dayofweek #returns the day of the week (Monday = 0, Sunday = 6)
df14['DOW'] = ind14.strftime('%a') #%a is the format string for Weekday Abbreviated name (Sun,Mon, etc.)

# %%
ind15 = pd.DatetimeIndex(df15['Start date']) #Use pandas.DatatimeIndex class for dealing with dates
df15['date'] = ind15.date.astype('datetime64') #creates an index with values cast to dtypes
df15['hour'] = ind15.hour #returns the hour from the datetime object
df15['Dayofweek'] = ind15.dayofweek #returns the day of the week (Monday = 0, Sunday = 6)
df15['DOW'] = ind15.strftime('%a') #%a is the format string for Weekday Abbreviated name (Sun,Mon, etc.)

# %%
fig, axes = plt.subplots(nrows=1, ncols=5,figsize=(24,5),sharey=True)
sns.countplot('hour',data=df11,order=range(25),palette="GnBu_d",ax=axes[0])
sns.countplot('hour',data=df12,order=range(25),palette="GnBu_d",ax=axes[1])
sns.countplot('hour',data=df13,order=range(25),palette="GnBu_d",ax=axes[2])
sns.countplot('hour',data=df14,order=range(25),palette="GnBu_d",ax=axes[3])
sns.countplot('hour',data=df15,order=range(25),palette="GnBu_d",ax=axes[4])
for ax in axes:
    ax.set_xlabel('Hour of the Day',fontsize=14)
    ax.set_ylabel('Number of Journeys')
axes[0].set_title('Total Trips by Time of Day - 2011',fontsize=16)
axes[1].set_title('Total Trips by Time of Day - 2012',fontsize=16)
axes[2].set_title('Total Trips by Time of Day - 2013',fontsize=16)
axes[3].set_title('Total Trips by Time of Day - 2014',fontsize=16)
axes[4].set_title('Total Trips by Time of Day - 2015',fontsize=16)
plt.tight_layout();
# Out:
# C:\ProgramData\Anaconda3_3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3_3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3_3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
##Year 2019 Traip Analysis.
